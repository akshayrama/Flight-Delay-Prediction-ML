# %%
import pandas as pd

# %%
dff16 = pd.read_csv('D:/Downloads/flighthead2k16new.csv')

# %%
dff16
# Out:
#         FlightDate  Quarter  Year  Month  DayofMonth  DepTime  DepDel15  \
# 0       2016-01-01        1  2016      1           1    741.0       0.0
# 1       2016-01-02        1  2016      1           2    737.0       0.0
# 2       2016-01-03        1  2016      1           3    743.0       0.0
# 3       2016-01-04        1  2016      1           4    737.0       0.0
# 4       2016-01-05        1  2016      1           5    708.0       0.0
# 5       2016-01-06        1  2016      1           6    703.0       0.0
# 6       2016-01-07        1  2016      1           7    704.0       0.0
# 7       2016-01-08        1  2016      1           8    701.0       0.0
# 8       2016-01-09        1  2016      1           9    703.0       0.0
# 9       2016-01-10        1  2016      1          10    711.0       0.0
# 10      2016-01-11        1  2016      1          11    709.0       0.0
# 11      2016-01-12        1  2016      1          12    636.0       0.0
# ...

# %%
dff16.shape
# Out:
# (936961, 22)

# %%
dfw16 = pd.read_csv('D:/Downloads/weatherdata2016.csv')

# %%
dfw16
# Out:
#         windspeedKmph  weatherCode  precipMM  WindGustKmph  pressure  \
# 0                  11          176       0.1            17      1023
# 1                  13          176       0.0            22      1023
# 2                  14          122       0.0            26      1023
# 3                  16          122       0.0            30      1023
# 4                  17          122       0.0            30      1023
# 5                  17          122       0.0            29      1024
# 6                  18          122       0.0            28      1024
# 7                  18          122       0.0            26      1024
# 8                  17          122       0.0            23      1025
# 9                  17          122       0.0            20      1025
# 10                 17          122       0.0            20      1025
# 11                 17          122       0.0            20      1025
# 12                 17          122       0.0            20      1025
# ...

# %%
dfw16.shape
# Out:
# (131760, 15)

# %%
df2016 = pd.DataFrame()

# %%
dfw16 = dfw16.rename(index = str,columns ={'airport': 'Origin'})

# %%
dfw16 = dfw16.rename(index = str,columns ={'time': 'RoundedCRSDepTime'})

# %%
dfw16 = dfw16.rename(index = str,columns ={'date': 'FlightDate'})

# %%
dfw16['FlightDate'] = pd.to_datetime(dfw16['FlightDate'])

# %%
dfw16.dtypes
# Out:
# windspeedKmph                 int64
# weatherCode                   int64
# precipMM                    float64
# WindGustKmph                  int64
# pressure                      int64
# cloudcover                    int64
# winddirDegree                 int64
# humidity                      int64
# cloudcover.1                  int64
# DewPointF                     int64
# tempF                         int64
# RoundedCRSDepTime             int64
# WindChillF                    int64
# FlightDate           datetime64[ns]
# Origin                       object
# dtype: object

# %%
dff16['FlightDate'] = pd.to_datetime(dff16['FlightDate'])

# %%
dff16.dtypes
# Out:
# FlightDate           datetime64[ns]
# Quarter                       int64
# Year                          int64
# Month                         int64
# DayofMonth                    int64
# DepTime                     float64
# DepDel15                    float64
# CRSDepTime                    int64
# DepDelayMinutes             float64
# OriginAirportID               int64
# Origin                       object
# DestAirportID                 int64
# Dest                         object
# ArrTime                     float64
# CRSArrTime                    int64
# ArrDel15                    float64
# ArrDelayMinutes             float64
# FlightArrDate                object
# RoundedDepTime              float64
# RoundedArrTime              float64
# RoundedCRSDepTime             int64
# RoundedCRSArrTime           float64
# dtype: object

# %%
df2016 = pd.merge(dff16,dfw16,on =['Origin','FlightDate','RoundedCRSDepTime'])

# %%
df2016
# Out:
#        FlightDate  Quarter  Year  Month  DayofMonth  DepTime  DepDel15  \
# 0      2016-01-01        1  2016      1           1    741.0       0.0
# 1      2016-01-01        1  2016      1           1    759.0       1.0
# 2      2016-01-01        1  2016      1           1    705.0       0.0
# 3      2016-01-01        1  2016      1           1    754.0       0.0
# 4      2016-01-01        1  2016      1           1    740.0       0.0
# 5      2016-01-01        1  2016      1           1    742.0       0.0
# 6      2016-01-01        1  2016      1           1    723.0       0.0
# 7      2016-01-01        1  2016      1           1    726.0       0.0
# 8      2016-01-01        1  2016      1           1    745.0       1.0
# 9      2016-01-01        1  2016      1           1    703.0       0.0
# 10     2016-01-02        1  2016      1           2    737.0       0.0
# 11     2016-01-02        1  2016      1           2    730.0       0.0
# ...

# %%
dfw16 = dfw16.rename(index = str,columns ={'Origin': 'Dest'})

# %%
dfw16 = dfw16.rename(index = str,columns ={'RoundedCRSDepTime': 'RoundedCRSArrTime'})

# %%
dfw16 = dfw16.rename(index = str,columns ={'FlightDate': 'FlightArrDate'})

# %%
dfw16.dtypes
# Out:
# windspeedKmph                 int64
# weatherCode                   int64
# precipMM                    float64
# WindGustKmph                  int64
# pressure                      int64
# cloudcover                    int64
# winddirDegree                 int64
# humidity                      int64
# cloudcover.1                  int64
# DewPointF                     int64
# tempF                         int64
# RoundedCRSArrTime             int64
# WindChillF                    int64
# FlightArrDate        datetime64[ns]
# Dest                         object
# dtype: object

# %%
df2016['FlightArrDate'] = pd.to_datetime(df2016['FlightArrDate'])

# %%
df2016 = pd.merge(df2016,dfw16,on = ['Dest','FlightArrDate','RoundedCRSArrTime'])

# %%
df2016
# Out:
#        FlightDate  Quarter  Year  Month  DayofMonth  DepTime  DepDel15  \
# 0      2016-01-01        1  2016      1           1    741.0       0.0
# 1      2016-01-01        1  2016      1           1   1408.0       1.0
# 2      2016-01-01        1  2016      1           1   1325.0       0.0
# 3      2016-01-01        1  2016      1           1   1306.0       0.0
# 4      2016-01-01        1  2016      1           1    758.0       0.0
# 5      2016-01-01        1  2016      1           1   1236.0       0.0
# 6      2016-01-01        1  2016      1           1   1144.0       0.0
# 7      2016-01-01        1  2016      1           1   1402.0       0.0
# 8      2016-01-01        1  2016      1           1    956.0       0.0
# 9      2016-01-01        1  2016      1           1   1437.0       0.0
# 10     2016-01-01        1  2016      1           1    759.0       1.0
# 11     2016-01-01        1  2016      1           1    748.0       0.0
# ...

# %%
df2016.shape
# Out:
# (936841, 46)

# %%
df2016.to_csv('D:/Downloads/df2016.csv',index = False, encoding = 'utf-8')

# %%
df2016.dtypes
# Out:
# FlightDate           datetime64[ns]
# Quarter                       int64
# Year                          int64
# Month                         int64
# DayofMonth                    int64
# DepTime                     float64
# DepDel15                    float64
# CRSDepTime                    int64
# DepDelayMinutes             float64
# OriginAirportID               int64
# Origin                       object
# DestAirportID                 int64
# Dest                         object
# ArrTime                     float64
# CRSArrTime                    int64
# ArrDel15                    float64
# ArrDelayMinutes             float64
# FlightArrDate        datetime64[ns]
# RoundedDepTime              float64
# RoundedArrTime              float64
# RoundedCRSDepTime             int64
# RoundedCRSArrTime           float64
# windspeedKmph_x               int64
# weatherCode_x                 int64
# precipMM_x                  float64
# WindGustKmph_x                int64
# ...

# %%
dff17 = pd.read_csv('D:/Downloads/flighthead2k17new.csv')

# %%
dff17
# Out:
#         FlightDate  Quarter  Year  Month  DayofMonth  DepTime  DepDel15  \
# 0       2017-01-17        1  2017      1          17   1616.0       0.0
# 1       2017-01-18        1  2017      1          18   1614.0       0.0
# 2       2017-01-19        1  2017      1          19   1611.0       0.0
# 3       2017-01-20        1  2017      1          20   1656.0       1.0
# 4       2017-01-21        1  2017      1          21   1632.0       0.0
# 5       2017-01-22        1  2017      1          22   1636.0       1.0
# 6       2017-01-23        1  2017      1          23   1616.0       0.0
# 7       2017-01-24        1  2017      1          24   1619.0       0.0
# 8       2017-01-25        1  2017      1          25   1616.0       0.0
# 9       2017-01-26        1  2017      1          26   1618.0       0.0
# 10      2017-01-27        1  2017      1          27   1613.0       0.0
# 11      2017-01-28        1  2017      1          28   1614.0       0.0
# ...

# %%
dff17.dtypes
# Out:
# FlightDate            object
# Quarter                int64
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DepTime              float64
# DepDel15             float64
# CRSDepTime             int64
# DepDelayMinutes      float64
# OriginAirportID        int64
# Origin                object
# DestAirportID          int64
# Dest                  object
# ArrTime              float64
# CRSArrTime             int64
# ArrDel15             float64
# ArrDelayMinutes      float64
# FlightArrDate         object
# RoundedDepTime       float64
# RoundedArrTime       float64
# RoundedCRSDepTime      int64
# RoundedCRSArrTime    float64
# dtype: object

# %%
dfw17 = pd.read_csv('D:/Downloads/weatherdata2017.csv')

# %%
dfw17
# Out:
#         windspeedKmph  weatherCode  precipMM  WindGustKmph  pressure  \
# 0                  15          266       0.3            23      1020
# 1                  15          266       0.3            22      1020
# 2                  14          353       0.3            21      1020
# 3                  14          353       0.3            21      1019
# 4                  13          353       0.7            21      1019
# 5                  12          302       1.2            21      1019
# 6                  12          302       1.6            21      1018
# 7                  12          302       2.4            22      1018
# 8                  12          302       3.1            23      1018
# 9                  12          302       3.9            25      1018
# 10                 12          302       4.0            24      1018
# 11                 12          302       4.1            23      1019
# 12                 12          302       4.2            22      1019
# ...

# %%
dfw17.dtypes
# Out:
# windspeedKmph      int64
# weatherCode        int64
# precipMM         float64
# WindGustKmph       int64
# pressure           int64
# cloudcover         int64
# winddirDegree      int64
# humidity           int64
# cloudcover.1       int64
# DewPointF          int64
# tempF              int64
# time               int64
# WindChillF         int64
# date              object
# airport           object
# dtype: object

# %%
df2017 = pd.DataFrame()

# %%
dfw17 = dfw17.rename(index = str,columns ={'airport': 'Origin'})

# %%
dfw17 = dfw17.rename(index = str,columns ={'time': 'RoundedCRSDepTime'})

# %%
dfw17 = dfw17.rename(index = str,columns ={'date': 'FlightDate'})

# %%
dfw17.dtypes
# Out:
# windspeedKmph          int64
# weatherCode            int64
# precipMM             float64
# WindGustKmph           int64
# pressure               int64
# cloudcover             int64
# winddirDegree          int64
# humidity               int64
# cloudcover.1           int64
# DewPointF              int64
# tempF                  int64
# RoundedCRSDepTime      int64
# WindChillF             int64
# FlightDate            object
# Origin                object
# dtype: object

# %%
dfw17['FlightDate'] = pd.to_datetime(dfw17['FlightDate'])

# %%
dff17['FlightArrDate'] = pd.to_datetime(dff17['FlightArrDate'])

# %%
dff17.dtypes
# Out:
# FlightDate           datetime64[ns]
# Quarter                       int64
# Year                          int64
# Month                         int64
# DayofMonth                    int64
# DepTime                     float64
# DepDel15                    float64
# CRSDepTime                    int64
# DepDelayMinutes             float64
# OriginAirportID               int64
# Origin                       object
# DestAirportID                 int64
# Dest                         object
# ArrTime                     float64
# CRSArrTime                    int64
# ArrDel15                    float64
# ArrDelayMinutes             float64
# FlightArrDate        datetime64[ns]
# RoundedDepTime              float64
# RoundedArrTime              float64
# RoundedCRSDepTime             int64
# RoundedCRSArrTime           float64
# dtype: object

# %%
df2017 = pd.merge(dff17,dfw17,on =['Origin','FlightDate','RoundedCRSDepTime'])

# %%
dff17['Origin']
# Out:
# 0         CLT
# 1         CLT
# 2         CLT
# 3         CLT
# 4         CLT
# 5         CLT
# 6         CLT
# 7         CLT
# 8         CLT
# 9         CLT
# 10        CLT
# 11        CLT
# 12        CLT
# 13        CLT
# 14        CLT
# 15        PHX
# 16        ATL
# 17        ATL
# 18        ATL
# 19        ATL
# 20        ATL
# 21        ATL
# 22        ATL
# 23        ATL
# 24        CLT
# 25        CLT
# 26        CLT
# 27        CLT
# 28        CLT
# 29        CLT
#          ...
# 914445    SFO
# 914446    JFK
# 914447    LAX
# 914448    JFK
# 914449    MCO
# 914450    SFO
# 914451    JFK
# 914452    LAX
# 914453    JFK
# 914454    MCO
# 914455    JFK
# 914456    JFK
# 914457    SFO
# 914458    JFK
# 914459    LAX
# 914460    MCO
# 914461    JFK
# 914462    MCO
# 914463    LAS
# 914464    JFK
# 914465    MCO
# 914466    JFK
# 914467    JFK
# 914468    ORD
# 914469    JFK
# 914470    SFO
# 914471    EWR
# 914472    MCO
# 914473    LAS
# 914474    MCO
# ...

# %%
dff17['FlightDate']
# Out:
# 0        2017-01-17
# 1        2017-01-18
# 2        2017-01-19
# 3        2017-01-20
# 4        2017-01-21
# 5        2017-01-22
# 6        2017-01-23
# 7        2017-01-24
# 8        2017-01-25
# 9        2017-01-26
# 10       2017-01-27
# 11       2017-01-28
# 12       2017-01-29
# 13       2017-01-30
# 14       2017-01-31
# 15       2017-01-06
# 16       2017-01-01
# 17       2017-01-02
# 18       2017-01-03
# 19       2017-01-04
# 20       2017-01-05
# 21       2017-01-06
# 22       2017-01-07
# 23       2017-01-08
# 24       2017-01-01
# 25       2017-01-02
# 26       2017-01-03
# 27       2017-01-04
# 28       2017-01-05
# 29       2017-01-06
#             ...
# 914445   2017-09-25
# 914446   2017-09-25
# 914447   2017-09-25
# 914448   2017-09-25
# 914449   2017-09-25
# 914450   2017-09-25
# 914451   2017-09-25
# 914452   2017-09-25
# 914453   2017-09-25
# 914454   2017-09-25
# 914455   2017-09-25
# 914456   2017-09-25
# 914457   2017-09-25
# 914458   2017-09-25
# ...

# %%
dfw17['Origin']
# Out:
# 0         ATL
# 1         ATL
# 2         ATL
# 3         ATL
# 4         ATL
# 5         ATL
# 6         ATL
# 7         ATL
# 8         ATL
# 9         ATL
# 10        ATL
# 11        ATL
# 12        ATL
# 13        ATL
# 14        ATL
# 15        ATL
# 16        ATL
# 17        ATL
# 18        ATL
# 19        ATL
# 20        ATL
# 21        ATL
# 22        ATL
# 23        ATL
# 24        ATL
# 25        ATL
# 26        ATL
# 27        ATL
# 28        ATL
# 29        ATL
#          ...
# 131370    SFO
# 131371    SFO
# 131372    SFO
# 131373    SFO
# 131374    SFO
# 131375    SFO
# 131376    SFO
# 131377    SFO
# 131378    SFO
# 131379    SFO
# 131380    SFO
# 131381    SFO
# 131382    SFO
# 131383    SFO
# 131384    SFO
# 131385    SFO
# 131386    SFO
# 131387    SFO
# 131388    SFO
# 131389    SFO
# 131390    SFO
# 131391    SFO
# 131392    SFO
# 131393    SFO
# 131394    SFO
# 131395    SFO
# 131396    SFO
# 131397    SFO
# 131398    SFO
# 131399    SFO
# ...

# %%
df2017
# Out:
#        FlightDate  Quarter  Year  Month  DayofMonth  DepTime  DepDel15  \
# 0      2017-01-17        1  2017      1          17   1616.0       0.0
# 1      2017-01-17        1  2017      1          17   1637.0       0.0
# 2      2017-01-17        1  2017      1          17   1700.0       1.0
# 3      2017-01-17        1  2017      1          17   1614.0       0.0
# 4      2017-01-17        1  2017      1          17   1626.0       0.0
# 5      2017-01-17        1  2017      1          17   1644.0       0.0
# 6      2017-01-17        1  2017      1          17   1618.0       0.0
# 7      2017-01-17        1  2017      1          17   1603.0       0.0
# 8      2017-01-17        1  2017      1          17   1626.0       0.0
# 9      2017-01-17        1  2017      1          17   1624.0       0.0
# 10     2017-01-17        1  2017      1          17   1613.0       0.0
# 11     2017-01-17        1  2017      1          17   1624.0       0.0
# ...

# %%
dff17.shape
# Out:
# (914475, 22)

# %%
dfw17.shape
# Out:
# (131400, 15)

# %%
dfw17 = dfw17.rename(index = str,columns ={'Origin': 'Dest'})

# %%
dfw17 = dfw17.rename(index = str,columns ={'RoundedCRSDepTime': 'RoundedCRSArrTime'})

# %%
dfw17 = dfw17.rename(index = str,columns ={'FlightDate': 'FlightArrDate'})

# %%
df2017['FlightArrDate'] = pd.to_datetime(df2017['FlightArrDate'])

# %%
df2017 = pd.merge(df2017,dfw17,on = ['Dest','FlightArrDate','RoundedCRSArrTime'])

# %%
df2017
# Out:
#        FlightDate  Quarter  Year  Month  DayofMonth  DepTime  DepDel15  \
# 0      2017-01-17        1  2017      1          17   1616.0       0.0
# 1      2017-01-17        1  2017      1          17   1624.0       0.0
# 2      2017-01-17        1  2017      1          17   1604.0       0.0
# 3      2017-01-17        1  2017      1          17   1629.0       0.0
# 4      2017-01-17        1  2017      1          17   1518.0       0.0
# 5      2017-01-17        1  2017      1          17   1621.0       1.0
# 6      2017-01-17        1  2017      1          17   1549.0       0.0
# 7      2017-01-17        1  2017      1          17   1533.0       0.0
# 8      2017-01-17        1  2017      1          17   1537.0       0.0
# 9      2017-01-17        1  2017      1          17   1632.0       0.0
# 10     2017-01-17        1  2017      1          17   1620.0       0.0
# 11     2017-01-17        1  2017      1          17   1628.0       0.0
# ...

# %%
df2017.to_csv('D:/Downloads/df2017.csv',index = False, encoding = 'utf-8')
